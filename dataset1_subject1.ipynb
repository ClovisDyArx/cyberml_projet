# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import mlsecu.data_exploration_utils as deu
import mlsecu.data_preparation_utils as dpu
import mlsecu.anomaly_detection_use_case as adu

from os import listdir

# %matplotlib inline

# %% [markdown]
# # Anomaly detection for tracking attacks
#
# This notebook contains our work for the objective "Anomaly detection for tracking attacks". We chose to use the dataset **A Hardware-in-the-Loop Water Distribution Testbed Dataset for Cyber-Physical Security Testing**.
#
# Our group is compose of *Clovis Lechien*, *Florian Segard-Gahery*, *Valentin San*, *Alexandre Devaux-Rivière* and *Maël Reynaud*.
#
# ## Dataset understanding and cleaning
#
# There is 2 type of sub-datasets in the dataset, which concerns network activity and physical activity. We will first have a look at the network ones, then the physical ones.
#
# ---

# %%
def get_summary(df):
    """
    This function allows us to have different metrics for each column of any dataset
    """
    df_desc = pd.DataFrame(df.describe(include='all').T)
    df_summary = pd.DataFrame({
        'dtype': df.dtypes,
        'unique':df.nunique().values,
        'missing': df.isna().sum().values,
        'duplicates': df.duplicated().sum(),
        'min': df_desc['min'].values,
        'max': df_desc['max'].values,
        'avg': df_desc['mean'].values,
        'std dev': df_desc['std'].values
    })
    return df_summary

# %% [markdown]
# ### Network datasets
#
# First, let's open each sub dataset and have a look at the different columns and values it contains.
#
# #### First dataset

# %%
df_net_attack_1 = pd.read_csv('./data/dataset/Network datatset/csv/attack_1.csv')
df_net_attack_1.head()
# Out:
#                          Time              mac_s              mac_d  \
# 0  2021-04-09 18:23:28.385003  74:46:a0:bd:a7:1b  0a:fe:ec:47:74:fb
# 1  2021-04-09 18:23:28.385005  74:46:a0:bd:a7:1b  e6:3f:ac:c9:a8:8c
# 2  2021-04-09 18:23:28.385006  74:46:a0:bd:a7:1b  fa:00:bc:90:d7:fa
# 3  2021-04-09 18:23:28.385484  0a:fe:ec:47:74:fb  74:46:a0:bd:a7:1b
# 4  2021-04-09 18:23:28.385486  fa:00:bc:90:d7:fa  74:46:a0:bd:a7:1b
#
#            ip_s          ip_d    sport    dport   proto    flags   size  \
# 0   84.3.251.20  84.3.251.102  56667.0    502.0  Modbus  11000.0     66
# 1   84.3.251.20  84.3.251.101  56666.0    502.0  Modbus  11000.0     66
# 2   84.3.251.20  84.3.251.103  56668.0    502.0  Modbus  11000.0     66
# 3  84.3.251.102   84.3.251.20    502.0  56667.0  Modbus  11000.0     64
# 4  84.3.251.103   84.3.251.20    502.0  56668.0  Modbus  11000.0     64
#
#              modbus_fn   n_pkt_src   n_pkt_dst  modbus_response   label_n  \
# 0   Read Coils Request         0.0         0.0              NaN         0
# 1   Read Coils Request         1.0         0.0              NaN         0
# 2   Read Coils Request         2.0         0.0              NaN         0
# 3  Read Coils Response         0.0         0.0              [0]         0
# 4  Read Coils Response         0.0         1.0              [0]         0
#
#     label
# 0  normal
# 1  normal
# 2  normal
# 3  normal
# 4  normal

# %%
get_summary(df_net_attack_1).style.background_gradient(cmap='viridis_r', low=0.8)
# Out:
# <style type="text/css">
# #T_3bd07_row0_col1, #T_3bd07_row13_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_3bd07_row0_col2, #T_3bd07_row1_col1, #T_3bd07_row1_col2, #T_3bd07_row2_col1, #T_3bd07_row2_col2, #T_3bd07_row3_col1, #T_3bd07_row3_col2, #T_3bd07_row4_col1, #T_3bd07_row4_col2, #T_3bd07_row5_col2, #T_3bd07_row6_col2, #T_3bd07_row7_col1, #T_3bd07_row7_col2, #T_3bd07_row8_col1, #T_3bd07_row8_col2, #T_3bd07_row9_col1, #T_3bd07_row9_col2, #T_3bd07_row10_col1, #T_3bd07_row11_col1, #T_3bd07_row11_col2, #T_3bd07_row12_col1, #T_3bd07_row12_col2, #T_3bd07_row13_col1, #T_3bd07_row14_col1, #T_3bd07_row14_col2, #T_3bd07_row15_col1, #T_3bd07_row15_col2 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_3bd07_row0_col3, #T_3bd07_row1_col3, #T_3bd07_row2_col3, #T_3bd07_row3_col3, #T_3bd07_row4_col3, #T_3bd07_row5_col3, #T_3bd07_row6_col3, #T_3bd07_row7_col3, #T_3bd07_row8_col3, #T_3bd07_row9_col3, #T_3bd07_row10_col3, #T_3bd07_row11_col3, #T_3bd07_row12_col3, #T_3bd07_row13_col3, #T_3bd07_row14_col3, #T_3bd07_row15_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_3bd07_row5_col1, #T_3bd07_row6_col1 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_3bd07_row10_col2 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3bd07">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3bd07_level0_col0" class="col_heading level0 col0" >dtype</th>
#       <th id="T_3bd07_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_3bd07_level0_col2" class="col_heading level0 col2" >missing</th>
#       <th id="T_3bd07_level0_col3" class="col_heading level0 col3" >duplicates</th>
#       <th id="T_3bd07_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_3bd07_level0_col5" class="col_heading level0 col5" >max</th>
#       <th id="T_3bd07_level0_col6" class="col_heading level0 col6" >avg</th>
#       <th id="T_3bd07_level0_col7" class="col_heading level0 col7" >std dev</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3bd07_level0_row0" class="row_heading level0 row0" >Time</th>
#       <td id="T_3bd07_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_3bd07_row0_col1" class="data row0 col1" >5242099</td>
#       <td id="T_3bd07_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_3bd07_row0_col3" class="data row0 col3" >2</td>
#       <td id="T_3bd07_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_3bd07_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_3bd07_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_3bd07_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3bd07_level0_row1" class="row_heading level0 row1" > mac_s</th>
#       <td id="T_3bd07_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_3bd07_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_3bd07_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_3bd07_row1_col3" class="data row1 col3" >2</td>
#       <td id="T_3bd07_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_3bd07_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_3bd07_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_3bd07_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3bd07_level0_row2" class="row_heading level0 row2" > mac_d</th>
#       <td id="T_3bd07_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_3bd07_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_3bd07_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_3bd07_row2_col3" class="data row2 col3" >2</td>
#       <td id="T_3bd07_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_3bd07_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_3bd07_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_3bd07_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3bd07_level0_row3" class="row_heading level0 row3" > ip_s</th>
#       <td id="T_3bd07_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_3bd07_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_3bd07_row3_col2" class="data row3 col2" >475</td>
#       <td id="T_3bd07_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_3bd07_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_3bd07_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_3bd07_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_3bd07_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3bd07_level0_row4" class="row_heading level0 row4" > ip_d</th>
#       <td id="T_3bd07_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_3bd07_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_3bd07_row4_col2" class="data row4 col2" >475</td>
#       <td id="T_3bd07_row4_col3" class="data row4 col3" >2</td>
#       <td id="T_3bd07_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_3bd07_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_3bd07_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_3bd07_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3bd07_level0_row5" class="row_heading level0 row5" > sport</th>
#       <td id="T_3bd07_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_3bd07_row5_col1" class="data row5 col1" >8445</td>
#       <td id="T_3bd07_row5_col2" class="data row5 col2" >515</td>
#       <td id="T_3bd07_row5_col3" class="data row5 col3" >2</td>
#       <td id="T_3bd07_row5_col4" class="data row5 col4" >25.000000</td>
#       <td id="T_3bd07_row5_col5" class="data row5 col5" >60999.000000</td>
#       <td id="T_3bd07_row5_col6" class="data row5 col6" >28496.742642</td>
#       <td id="T_3bd07_row5_col7" class="data row5 col7" >27966.236571</td>
#     </tr>
#     <tr>
#       <th id="T_3bd07_level0_row6" class="row_heading level0 row6" > dport</th>
#       <td id="T_3bd07_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_3bd07_row6_col1" class="data row6 col1" >8441</td>
#       <td id="T_3bd07_row6_col2" class="data row6 col2" >515</td>
#       <td id="T_3bd07_row6_col3" class="data row6 col3" >2</td>
#       <td id="T_3bd07_row6_col4" class="data row6 col4" >25.000000</td>
#       <td id="T_3bd07_row6_col5" class="data row6 col5" >60999.000000</td>
#       <td id="T_3bd07_row6_col6" class="data row6 col6" >28370.122168</td>
#       <td id="T_3bd07_row6_col7" class="data row6 col7" >27984.759506</td>
#     </tr>
#     <tr>
#       <th id="T_3bd07_level0_row7" class="row_heading level0 row7" > proto</th>
#       <td id="T_3bd07_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_3bd07_row7_col1" class="data row7 col1" >4</td>
#       <td id="T_3bd07_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_3bd07_row7_col3" class="data row7 col3" >2</td>
#       <td id="T_3bd07_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_3bd07_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_3bd07_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_3bd07_row7_col7" class="data row7 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_3bd07_level0_row8" class="row_heading level0 row8" > flags</th>
#       <td id="T_3bd07_row8_col0" class="data row8 col0" >float64</td>
#       <td id="T_3bd07_row8_col1" class="data row8 col1" >7</td>
#       <td id="T_3bd07_row8_col2" class="data row8 col2" >515</td>
#       <td id="T_3bd07_row8_col3" class="data row8 col3" >2</td>
#       <td id="T_3bd07_row8_col4" class="data row8 col4" >10.000000</td>
#       <td id="T_3bd07_row8_col5" class="data row8 col5" >11000.000000</td>
#       <td id="T_3bd07_row8_col6" class="data row8 col6" >10916.886999</td>
#       <td id="T_3bd07_row8_col7" class="data row8 col7" >839.861839</td>
#     </tr>
#     <tr>
#       <th id="T_3bd07_level0_row9" class="row_heading level0 row9" > size</th>
#       <td id="T_3bd07_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_3bd07_row9_col1" class="data row9 col1" >7</td>
#       <td id="T_3bd07_row9_col2" c

# %%
df_net_attack_1[df_net_attack_1[" label_n"] == 0][" label"].unique()
# Out:
# array(['normal'], dtype=object)

# %%
df_net_attack_1[df_net_attack_1[" label_n"] == 1][" label"].unique()
# Out:
# array(['anomaly', 'MITM', 'physical fault'], dtype=object)

# %% [markdown]
# The dataset file name can be misleading, in this first dataset called **attack_1.csv**, we have attacks recording but also normal ones.
#
# Also, the columns contains whitespace before their names, so we better remove them to concatenate them after.

# %%
df_net_attack_1.columns
# Out:
# Index(['Time', ' mac_s', ' mac_d', ' ip_s', ' ip_d', ' sport', ' dport',
#        ' proto', ' flags', ' size', ' modbus_fn', ' n_pkt_src', ' n_pkt_dst',
#        ' modbus_response', ' label_n', ' label'],
#       dtype='object')

# %%
df_net_attack_1.columns = df_net_attack_1.columns.str.strip()

# %%
df_net_attack_1.columns
# Out:
# Index(['Time', 'mac_s', 'mac_d', 'ip_s', 'ip_d', 'sport', 'dport', 'proto',
#        'flags', 'size', 'modbus_fn', 'n_pkt_src', 'n_pkt_dst',
#        'modbus_response', 'label_n', 'label'],
#       dtype='object')

# %% [markdown]
# #### Second dataset

# %%
df_net_attack_2 = pd.read_csv('./data/dataset/Network datatset/csv/attack_2.csv')
df_net_attack_2.head()
# Out:
#                          Time              mac_s              mac_d  \
# 0  2021-04-19 15:37:19.989214  00:80:f4:03:fb:12  74:46:a0:bd:a7:1b
# 1  2021-04-19 15:37:19.990641  74:46:a0:bd:a7:1b  e6:3f:ac:c9:a8:8c
# 2  2021-04-19 15:37:19.990645  74:46:a0:bd:a7:1b  0a:fe:ec:47:74:fb
# 3  2021-04-19 15:37:19.990647  74:46:a0:bd:a7:1b  fa:00:bc:90:d7:fa
# 4  2021-04-19 15:37:19.990943  e6:3f:ac:c9:a8:8c  74:46:a0:bd:a7:1b
#
#            ip_s          ip_d    sport    dport   proto    flags   size  \
# 0   84.3.251.18   84.3.251.20    502.0  61315.0  Modbus  11000.0     64
# 1   84.3.251.20  84.3.251.101  61316.0    502.0  Modbus  11000.0     66
# 2   84.3.251.20  84.3.251.102  61318.0    502.0  Modbus  11000.0     66
# 3   84.3.251.20  84.3.251.103  61317.0    502.0  Modbus  11000.0     66
# 4  84.3.251.101   84.3.251.20    502.0  61316.0  Modbus  11000.0     65
#
#                          modbus_fn   n_pkt_src   n_pkt_dst  modbus_response  \
# 0              Read Coils Response         0.0         0.0              [0]
# 1           Read Holding Registers         0.0         0.0              NaN
# 2           Read Holding Registers         1.0         0.0              NaN
# 3               Read Coils Request         2.0         0.0              NaN
# 4  Read Holding Registers Response         0.0         1.0              [0]
#
#     label_n   label
# 0         0  normal
# 1         0  normal
# 2         0  normal
# 3         0  normal
# 4         0  normal

# %%
get_summary(df_net_attack_2).style.background_gradient(cmap='viridis_r', low=0.8)
# Out:
# <style type="text/css">
# #T_c9271_row0_col1, #T_c9271_row13_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_c9271_row0_col2, #T_c9271_row1_col1, #T_c9271_row1_col2, #T_c9271_row2_col1, #T_c9271_row2_col2, #T_c9271_row3_col1, #T_c9271_row3_col2, #T_c9271_row4_col1, #T_c9271_row4_col2, #T_c9271_row7_col1, #T_c9271_row7_col2, #T_c9271_row8_col1, #T_c9271_row9_col1, #T_c9271_row9_col2, #T_c9271_row10_col1, #T_c9271_row11_col1, #T_c9271_row11_col2, #T_c9271_row12_col1, #T_c9271_row12_col2, #T_c9271_row13_col1, #T_c9271_row14_col1, #T_c9271_row14_col2, #T_c9271_row15_col1, #T_c9271_row15_col2 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_c9271_row0_col3, #T_c9271_row1_col3, #T_c9271_row2_col3, #T_c9271_row3_col3, #T_c9271_row4_col3, #T_c9271_row5_col3, #T_c9271_row6_col3, #T_c9271_row7_col3, #T_c9271_row8_col3, #T_c9271_row9_col3, #T_c9271_row10_col3, #T_c9271_row11_col3, #T_c9271_row12_col3, #T_c9271_row13_col3, #T_c9271_row14_col3, #T_c9271_row15_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_c9271_row5_col1, #T_c9271_row6_col1 {
#   background-color: #1e9d89;
#   color: #f1f1f1;
# }
# #T_c9271_row5_col2, #T_c9271_row6_col2, #T_c9271_row8_col2 {
#   background-color: #228b8d;
#   color: #f1f1f1;
# }
# #T_c9271_row10_col2 {
#   background-color: #25848e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c9271">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c9271_level0_col0" class="col_heading level0 col0" >dtype</th>
#       <th id="T_c9271_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_c9271_level0_col2" class="col_heading level0 col2" >missing</th>
#       <th id="T_c9271_level0_col3" class="col_heading level0 col3" >duplicates</th>
#       <th id="T_c9271_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_c9271_level0_col5" class="col_heading level0 col5" >max</th>
#       <th id="T_c9271_level0_col6" class="col_heading level0 col6" >avg</th>
#       <th id="T_c9271_level0_col7" class="col_heading level0 col7" >std dev</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c9271_level0_row0" class="row_heading level0 row0" >Time</th>
#       <td id="T_c9271_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_c9271_row0_col1" class="data row0 col1" >5157725</td>
#       <td id="T_c9271_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_c9271_row0_col3" class="data row0 col3" >349</td>
#       <td id="T_c9271_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_c9271_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_c9271_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_c9271_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9271_level0_row1" class="row_heading level0 row1" > mac_s</th>
#       <td id="T_c9271_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_c9271_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_c9271_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_c9271_row1_col3" class="data row1 col3" >349</td>
#       <td id="T_c9271_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_c9271_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_c9271_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_c9271_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9271_level0_row2" class="row_heading level0 row2" > mac_d</th>
#       <td id="T_c9271_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_c9271_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_c9271_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_c9271_row2_col3" class="data row2 col3" >349</td>
#       <td id="T_c9271_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_c9271_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_c9271_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_c9271_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9271_level0_row3" class="row_heading level0 row3" > ip_s</th>
#       <td id="T_c9271_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_c9271_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_c9271_row3_col2" class="data row3 col2" >276</td>
#       <td id="T_c9271_row3_col3" class="data row3 col3" >349</td>
#       <td id="T_c9271_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_c9271_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_c9271_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_c9271_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9271_level0_row4" class="row_heading level0 row4" > ip_d</th>
#       <td id="T_c9271_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_c9271_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_c9271_row4_col2" class="data row4 col2" >276</td>
#       <td id="T_c9271_row4_col3" class="data row4 col3" >349</td>
#       <td id="T_c9271_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_c9271_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_c9271_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_c9271_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9271_level0_row5" class="row_heading level0 row5" > sport</th>
#       <td id="T_c9271_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_c9271_row5_col1" class="data row5 col1" >23748</td>
#       <td id="T_c9271_row5_col2" class="data row5 col2" >385383</td>
#       <td id="T_c9271_row5_col3" class="data row5 col3" >349</td>
#       <td id="T_c9271_row5_col4" class="data row5 col4" >25.000000</td>
#       <td id="T_c9271_row5_col5" class="data row5 col5" >61646.000000</td>
#       <td id="T_c9271_row5_col6" class="data row5 col6" >30643.369958</td>
#       <td id="T_c9271_row5_col7" class="data row5 col7" >30218.012482</td>
#     </tr>
#     <tr>
#       <th id="T_c9271_level0_row6" class="row_heading level0 row6" > dport</th>
#       <td id="T_c9271_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_c9271_row6_col1" class="data row6 col1" >9475</td>
#       <td id="T_c9271_row6_col2" class="data row6 col2" >385383</td>
#       <td id="T_c9271_row6_col3" class="data row6 col3" >349</td>
#       <td id="T_c9271_row6_col4" class="data row6 col4" >25.000000</td>
#       <td id="T_c9271_row6_col5" class="data row6 col5" >61646.000000</td>
#       <td id="T_c9271_row6_col6" class="data row6 col6" >30469.679920</td>
#       <td id="T_c9271_row6_col7" class="data row6 col7" >30275.374820</td>
#     </tr>
#     <tr>
#       <th id="T_c9271_level0_row7" class="row_heading level0 row7" > proto</th>
#       <td id="T_c9271_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_c9271_row7_col1" class="data row7 col1" >4</td>
#       <td id="T_c9271_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_c9271_row7_col3" class="data row7 col3" >349</td>
#       <td id="T_c9271_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_c9271_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_c9271_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_c9271_row7_col7" class="data row7 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c9271_level0_row8" class="row_heading level0 row8" > flags</th>
#       <td id="T_c9271_row8_col0" class="data row8 col0" >float64</td>
#       <td id="T_c9271_row8_col1" class="data row8 col1" >12</td>
#       <td id="T_c9271_row8_col2" class="data row8 col2" >385383</td>
#       <td id="T_c9271_row8_col3" class="data row8 col3" >349</td>
#       <td id="T_c9271_row8_col4" class="data row8 col4" >0.000000</td>
#       <td id="T_c9271_row8_col5" class="data row8 col5" >11000010.000000</td>
#       <td id="T_c9271_row8_col6" class="data row8 col6" >10881.941764</td>
#       <td id="T_c9271_row8_col7" class="data row8 col7" >13354.240130</td>
#     </tr>
#     <tr>
#       <th id="T_c9271_level0_row9" class="row_heading level0 row9" > size</th>
#       <td id="T_c9271_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T

# %%
df_net_attack_2.columns = df_net_attack_2.columns.str.strip()

# %% [markdown]
# #### Third dataset

# %%
df_net_attack_3 = pd.read_csv('./data/dataset/Network datatset/csv/attack_3.csv')
df_net_attack_3.head()
# Out:
#                          Time              mac_s              mac_d  \
# 0  2021-04-09 19:42:13.484804  00:80:f4:03:fb:12  74:46:a0:bd:a7:1b
# 1  2021-04-09 19:42:13.487062  74:46:a0:bd:a7:1b  0a:fe:ec:47:74:fb
# 2  2021-04-09 19:42:13.487078  74:46:a0:bd:a7:1b  fa:00:bc:90:d7:fa
# 3  2021-04-09 19:42:13.487079  74:46:a0:bd:a7:1b  00:80:f4:03:fb:12
# 4  2021-04-09 19:42:13.487080  74:46:a0:bd:a7:1b  e6:3f:ac:c9:a8:8c
#
#           ip_s          ip_d    sport    dport   proto    flags   size  \
# 0  84.3.251.18   84.3.251.20    502.0  57939.0  Modbus  11000.0     64
# 1  84.3.251.20  84.3.251.102  57940.0    502.0  Modbus  11000.0     66
# 2  84.3.251.20  84.3.251.103  57942.0    502.0  Modbus  11000.0     66
# 3  84.3.251.20   84.3.251.18  57939.0    502.0  Modbus  11000.0     66
# 4  84.3.251.20  84.3.251.101  57941.0    502.0  Modbus  11000.0     66
#
#                 modbus_fn   n_pkt_src   n_pkt_dst  modbus_response   label_n  \
# 0     Read Coils Response         0.0         0.0              [0]         0
# 1  Read Holding Registers         0.0         0.0              NaN         0
# 2  Read Holding Registers         1.0         0.0              NaN         0
# 3      Read Coils Request         2.0         0.0              NaN         0
# 4  Read Holding Registers         3.0         0.0              NaN         0
#
#     label
# 0  normal
# 1  normal
# 2  normal
# 3  normal
# 4  normal

# %%
get_summary(df_net_attack_3).style.background_gradient(cmap='viridis_r', low=0.8)
# Out:
# <style type="text/css">
# #T_c15a7_row0_col1, #T_c15a7_row13_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_c15a7_row0_col2, #T_c15a7_row1_col1, #T_c15a7_row1_col2, #T_c15a7_row2_col1, #T_c15a7_row2_col2, #T_c15a7_row3_col1, #T_c15a7_row3_col2, #T_c15a7_row4_col1, #T_c15a7_row4_col2, #T_c15a7_row5_col1, #T_c15a7_row6_col1, #T_c15a7_row7_col1, #T_c15a7_row7_col2, #T_c15a7_row8_col1, #T_c15a7_row9_col1, #T_c15a7_row9_col2, #T_c15a7_row10_col1, #T_c15a7_row11_col1, #T_c15a7_row11_col2, #T_c15a7_row12_col1, #T_c15a7_row12_col2, #T_c15a7_row13_col1, #T_c15a7_row14_col1, #T_c15a7_row14_col2, #T_c15a7_row15_col1, #T_c15a7_row15_col2 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_c15a7_row0_col3, #T_c15a7_row1_col3, #T_c15a7_row2_col3, #T_c15a7_row3_col3, #T_c15a7_row4_col3, #T_c15a7_row5_col3, #T_c15a7_row6_col3, #T_c15a7_row7_col3, #T_c15a7_row8_col3, #T_c15a7_row9_col3, #T_c15a7_row10_col3, #T_c15a7_row11_col3, #T_c15a7_row12_col3, #T_c15a7_row13_col3, #T_c15a7_row14_col3, #T_c15a7_row15_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_c15a7_row5_col2, #T_c15a7_row6_col2, #T_c15a7_row8_col2 {
#   background-color: #433d84;
#   color: #f1f1f1;
# }
# #T_c15a7_row10_col2 {
#   background-color: #443983;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c15a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c15a7_level0_col0" class="col_heading level0 col0" >dtype</th>
#       <th id="T_c15a7_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_c15a7_level0_col2" class="col_heading level0 col2" >missing</th>
#       <th id="T_c15a7_level0_col3" class="col_heading level0 col3" >duplicates</th>
#       <th id="T_c15a7_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_c15a7_level0_col5" class="col_heading level0 col5" >max</th>
#       <th id="T_c15a7_level0_col6" class="col_heading level0 col6" >avg</th>
#       <th id="T_c15a7_level0_col7" class="col_heading level0 col7" >std dev</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c15a7_level0_row0" class="row_heading level0 row0" >Time</th>
#       <td id="T_c15a7_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_c15a7_row0_col1" class="data row0 col1" >5678943</td>
#       <td id="T_c15a7_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_c15a7_row0_col3" class="data row0 col3" >118270</td>
#       <td id="T_c15a7_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_c15a7_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_c15a7_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_c15a7_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c15a7_level0_row1" class="row_heading level0 row1" > mac_s</th>
#       <td id="T_c15a7_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_c15a7_row1_col1" class="data row1 col1" >8</td>
#       <td id="T_c15a7_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_c15a7_row1_col3" class="data row1 col3" >118270</td>
#       <td id="T_c15a7_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_c15a7_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_c15a7_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_c15a7_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c15a7_level0_row2" class="row_heading level0 row2" > mac_d</th>
#       <td id="T_c15a7_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_c15a7_row2_col1" class="data row2 col1" >9</td>
#       <td id="T_c15a7_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_c15a7_row2_col3" class="data row2 col3" >118270</td>
#       <td id="T_c15a7_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_c15a7_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_c15a7_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_c15a7_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c15a7_level0_row3" class="row_heading level0 row3" > ip_s</th>
#       <td id="T_c15a7_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_c15a7_row3_col1" class="data row3 col1" >8</td>
#       <td id="T_c15a7_row3_col2" class="data row3 col2" >189</td>
#       <td id="T_c15a7_row3_col3" class="data row3 col3" >118270</td>
#       <td id="T_c15a7_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_c15a7_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_c15a7_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_c15a7_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c15a7_level0_row4" class="row_heading level0 row4" > ip_d</th>
#       <td id="T_c15a7_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_c15a7_row4_col1" class="data row4 col1" >8</td>
#       <td id="T_c15a7_row4_col2" class="data row4 col2" >189</td>
#       <td id="T_c15a7_row4_col3" class="data row4 col3" >118270</td>
#       <td id="T_c15a7_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_c15a7_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_c15a7_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_c15a7_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c15a7_level0_row5" class="row_heading level0 row5" > sport</th>
#       <td id="T_c15a7_row5_col0" class="data row5 col0" >float64</td>
#       <td id="T_c15a7_row5_col1" class="data row5 col1" >5284</td>
#       <td id="T_c15a7_row5_col2" class="data row5 col2" >3066837</td>
#       <td id="T_c15a7_row5_col3" class="data row5 col3" >118270</td>
#       <td id="T_c15a7_row5_col4" class="data row5 col4" >502.000000</td>
#       <td id="T_c15a7_row5_col5" class="data row5 col5" >60999.000000</td>
#       <td id="T_c15a7_row5_col6" class="data row5 col6" >29144.076738</td>
#       <td id="T_c15a7_row5_col7" class="data row5 col7" >28617.223644</td>
#     </tr>
#     <tr>
#       <th id="T_c15a7_level0_row6" class="row_heading level0 row6" > dport</th>
#       <td id="T_c15a7_row6_col0" class="data row6 col0" >float64</td>
#       <td id="T_c15a7_row6_col1" class="data row6 col1" >5276</td>
#       <td id="T_c15a7_row6_col2" class="data row6 col2" >3066837</td>
#       <td id="T_c15a7_row6_col3" class="data row6 col3" >118270</td>
#       <td id="T_c15a7_row6_col4" class="data row6 col4" >502.000000</td>
#       <td id="T_c15a7_row6_col5" class="data row6 col5" >60999.000000</td>
#       <td id="T_c15a7_row6_col6" class="data row6 col6" >29015.472308</td>
#       <td id="T_c15a7_row6_col7" class="data row6 col7" >28638.323882</td>
#     </tr>
#     <tr>
#       <th id="T_c15a7_level0_row7" class="row_heading level0 row7" > proto</th>
#       <td id="T_c15a7_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_c15a7_row7_col1" class="data row7 col1" >5</td>
#       <td id="T_c15a7_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_c15a7_row7_col3" class="data row7 col3" >118270</td>
#       <td id="T_c15a7_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_c15a7_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_c15a7_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_c15a7_row7_col7" class="data row7 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_c15a7_level0_row8" class="row_heading level0 row8" > flags</th>
#       <td id="T_c15a7_row8_col0" class="data row8 col0" >float64</td>
#       <td id="T_c15a7_row8_col1" class="data row8 col1" >9</td>
#       <td id="T_c15a7_row8_col2" class="data row8 col2" >3066837</td>
#       <td id="T_c15a7_row8_col3" class="data row8 col3" >118270</td>
#       <td id="T_c15a7_row8_col4" class="data row8 col4" >10.000000</td>
#       <td id="T_c15a7_row8_col5" class="data row8 col5" >11000010.000000</td>
#       <td id="T_c15a7_row8_col6" class="data row8 col6" >11011.663764</td>
#       <td id="T_c15a7_row8_col7" class="data row8 col7" >32208.195023</td>
#     </tr>
#     <tr>
#       <th id="T_c15a7_level0_row9" class="row_heading level0 row9" > size</th>
#       <td id="T_c15a7_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_c15a7_row9_col1" c

# %%
df_net_attack_3.columns = df_net_attack_3.columns.str.strip()

# %% [markdown]
# #### Fourth dataset

# %%
df_net_normal = pd.read_csv('./data/dataset/Network datatset/csv/normal.csv')
df_net_normal.head()
# Out:
#                          Time              mac_s              mac_d  \
# 0  2021-04-09 11:30:52.716203  74:46:a0:bd:a7:1b  fa:00:bc:90:d7:fa
# 1  2021-04-09 11:30:52.716499  fa:00:bc:90:d7:fa  74:46:a0:bd:a7:1b
# 2  2021-04-09 11:30:52.717334  74:46:a0:bd:a7:1b  e6:3f:ac:c9:a8:8c
# 3  2021-04-09 11:30:52.717624  e6:3f:ac:c9:a8:8c  74:46:a0:bd:a7:1b
# 4  2021-04-09 11:30:52.717952  00:80:f4:03:fb:12  74:46:a0:bd:a7:1b
#
#            ip_s          ip_d  sport  dport   proto  flags  size  \
# 0   84.3.251.20  84.3.251.103  61516    502  Modbus  11000    66
# 1  84.3.251.103   84.3.251.20    502  61516  Modbus  11000    65
# 2   84.3.251.20  84.3.251.101  61515    502  Modbus  11000    66
# 3  84.3.251.101   84.3.251.20    502  61515  Modbus  11000    65
# 4   84.3.251.18   84.3.251.20    502  61514  Modbus  11000    64
#
#                          modbus_fn  n_pkt_src  n_pkt_dst modbus_response  \
# 0           Read Holding Registers          0          0             NaN
# 1  Read Holding Registers Response          0          0             [0]
# 2           Read Holding Registers          1          0             NaN
# 3  Read Holding Registers Response          0          1             [0]
# 4              Read Coils Response          0          2             [0]
#
#    label_n   label
# 0        0  normal
# 1        0  normal
# 2        0  normal
# 3        0  normal
# 4        0  normal

# %%
get_summary(df_net_normal).style.background_gradient(cmap='viridis_r', low=0.8)
# Out:
# <style type="text/css">
# #T_91105_row0_col1, #T_91105_row13_col2 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_91105_row0_col2, #T_91105_row1_col1, #T_91105_row1_col2, #T_91105_row2_col1, #T_91105_row2_col2, #T_91105_row3_col1, #T_91105_row3_col2, #T_91105_row4_col1, #T_91105_row4_col2, #T_91105_row5_col1, #T_91105_row5_col2, #T_91105_row6_col1, #T_91105_row6_col2, #T_91105_row7_col1, #T_91105_row7_col2, #T_91105_row8_col1, #T_91105_row8_col2, #T_91105_row9_col1, #T_91105_row9_col2, #T_91105_row10_col1, #T_91105_row11_col1, #T_91105_row11_col2, #T_91105_row12_col1, #T_91105_row12_col2, #T_91105_row13_col1, #T_91105_row14_col1, #T_91105_row14_col2, #T_91105_row15_col1, #T_91105_row15_col2 {
#   background-color: #1f9e89;
#   color: #f1f1f1;
# }
# #T_91105_row0_col3, #T_91105_row1_col3, #T_91105_row2_col3, #T_91105_row3_col3, #T_91105_row4_col3, #T_91105_row5_col3, #T_91105_row6_col3, #T_91105_row7_col3, #T_91105_row8_col3, #T_91105_row9_col3, #T_91105_row10_col3, #T_91105_row11_col3, #T_91105_row12_col3, #T_91105_row13_col3, #T_91105_row14_col3, #T_91105_row15_col3 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_91105_row10_col2 {
#   background-color: #1f968b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_91105">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_91105_level0_col0" class="col_heading level0 col0" >dtype</th>
#       <th id="T_91105_level0_col1" class="col_heading level0 col1" >unique</th>
#       <th id="T_91105_level0_col2" class="col_heading level0 col2" >missing</th>
#       <th id="T_91105_level0_col3" class="col_heading level0 col3" >duplicates</th>
#       <th id="T_91105_level0_col4" class="col_heading level0 col4" >min</th>
#       <th id="T_91105_level0_col5" class="col_heading level0 col5" >max</th>
#       <th id="T_91105_level0_col6" class="col_heading level0 col6" >avg</th>
#       <th id="T_91105_level0_col7" class="col_heading level0 col7" >std dev</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_91105_level0_row0" class="row_heading level0 row0" >Time</th>
#       <td id="T_91105_row0_col0" class="data row0 col0" >object</td>
#       <td id="T_91105_row0_col1" class="data row0 col1" >7128712</td>
#       <td id="T_91105_row0_col2" class="data row0 col2" >0</td>
#       <td id="T_91105_row0_col3" class="data row0 col3" >0</td>
#       <td id="T_91105_row0_col4" class="data row0 col4" >nan</td>
#       <td id="T_91105_row0_col5" class="data row0 col5" >nan</td>
#       <td id="T_91105_row0_col6" class="data row0 col6" >nan</td>
#       <td id="T_91105_row0_col7" class="data row0 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_91105_level0_row1" class="row_heading level0 row1" >mac_s</th>
#       <td id="T_91105_row1_col0" class="data row1 col0" >object</td>
#       <td id="T_91105_row1_col1" class="data row1 col1" >7</td>
#       <td id="T_91105_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_91105_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_91105_row1_col4" class="data row1 col4" >nan</td>
#       <td id="T_91105_row1_col5" class="data row1 col5" >nan</td>
#       <td id="T_91105_row1_col6" class="data row1 col6" >nan</td>
#       <td id="T_91105_row1_col7" class="data row1 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_91105_level0_row2" class="row_heading level0 row2" >mac_d</th>
#       <td id="T_91105_row2_col0" class="data row2 col0" >object</td>
#       <td id="T_91105_row2_col1" class="data row2 col1" >7</td>
#       <td id="T_91105_row2_col2" class="data row2 col2" >0</td>
#       <td id="T_91105_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_91105_row2_col4" class="data row2 col4" >nan</td>
#       <td id="T_91105_row2_col5" class="data row2 col5" >nan</td>
#       <td id="T_91105_row2_col6" class="data row2 col6" >nan</td>
#       <td id="T_91105_row2_col7" class="data row2 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_91105_level0_row3" class="row_heading level0 row3" >ip_s</th>
#       <td id="T_91105_row3_col0" class="data row3 col0" >object</td>
#       <td id="T_91105_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_91105_row3_col2" class="data row3 col2" >0</td>
#       <td id="T_91105_row3_col3" class="data row3 col3" >0</td>
#       <td id="T_91105_row3_col4" class="data row3 col4" >nan</td>
#       <td id="T_91105_row3_col5" class="data row3 col5" >nan</td>
#       <td id="T_91105_row3_col6" class="data row3 col6" >nan</td>
#       <td id="T_91105_row3_col7" class="data row3 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_91105_level0_row4" class="row_heading level0 row4" >ip_d</th>
#       <td id="T_91105_row4_col0" class="data row4 col0" >object</td>
#       <td id="T_91105_row4_col1" class="data row4 col1" >7</td>
#       <td id="T_91105_row4_col2" class="data row4 col2" >0</td>
#       <td id="T_91105_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_91105_row4_col4" class="data row4 col4" >nan</td>
#       <td id="T_91105_row4_col5" class="data row4 col5" >nan</td>
#       <td id="T_91105_row4_col6" class="data row4 col6" >nan</td>
#       <td id="T_91105_row4_col7" class="data row4 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_91105_level0_row5" class="row_heading level0 row5" >sport</th>
#       <td id="T_91105_row5_col0" class="data row5 col0" >int64</td>
#       <td id="T_91105_row5_col1" class="data row5 col1" >10261</td>
#       <td id="T_91105_row5_col2" class="data row5 col2" >0</td>
#       <td id="T_91105_row5_col3" class="data row5 col3" >0</td>
#       <td id="T_91105_row5_col4" class="data row5 col4" >25.000000</td>
#       <td id="T_91105_row5_col5" class="data row5 col5" >61517.000000</td>
#       <td id="T_91105_row5_col6" class="data row5 col6" >30848.979497</td>
#       <td id="T_91105_row5_col7" class="data row5 col7" >30341.080063</td>
#     </tr>
#     <tr>
#       <th id="T_91105_level0_row6" class="row_heading level0 row6" >dport</th>
#       <td id="T_91105_row6_col0" class="data row6 col0" >int64</td>
#       <td id="T_91105_row6_col1" class="data row6 col1" >10261</td>
#       <td id="T_91105_row6_col2" class="data row6 col2" >0</td>
#       <td id="T_91105_row6_col3" class="data row6 col3" >0</td>
#       <td id="T_91105_row6_col4" class="data row6 col4" >25.000000</td>
#       <td id="T_91105_row6_col5" class="data row6 col5" >61517.000000</td>
#       <td id="T_91105_row6_col6" class="data row6 col6" >30726.536132</td>
#       <td id="T_91105_row6_col7" class="data row6 col7" >30366.784408</td>
#     </tr>
#     <tr>
#       <th id="T_91105_level0_row7" class="row_heading level0 row7" >proto</th>
#       <td id="T_91105_row7_col0" class="data row7 col0" >object</td>
#       <td id="T_91105_row7_col1" class="data row7 col1" >2</td>
#       <td id="T_91105_row7_col2" class="data row7 col2" >0</td>
#       <td id="T_91105_row7_col3" class="data row7 col3" >0</td>
#       <td id="T_91105_row7_col4" class="data row7 col4" >nan</td>
#       <td id="T_91105_row7_col5" class="data row7 col5" >nan</td>
#       <td id="T_91105_row7_col6" class="data row7 col6" >nan</td>
#       <td id="T_91105_row7_col7" class="data row7 col7" >nan</td>
#     </tr>
#     <tr>
#       <th id="T_91105_level0_row8" class="row_heading level0 row8" >flags</th>
#       <td id="T_91105_row8_col0" class="data row8 col0" >int64</td>
#       <td id="T_91105_row8_col1" class="data row8 col1" >7</td>
#       <td id="T_91105_row8_col2" class="data row8 col2" >0</td>
#       <td id="T_91105_row8_col3" class="data row8 col3" >0</td>
#       <td id="T_91105_row8_col4" class="data row8 col4" >10.000000</td>
#       <td id="T_91105_row8_col5" class="data row8 col5" >11000.000000</td>
#       <td id="T_91105_row8_col6" class="data row8 col6" >10918.518061</td>
#       <td id="T_91105_row8_col7" class="data row8 col7" >831.540578</td>
#     </tr>
#     <tr>
#       <th id="T_91105_level0_row9" class="row_heading level0 row9" >size</th>
#       <td id="T_91105_row9_col0" class="data row9 col0" >int64</td>
#       <td id="T_91105_row9_col1" class="data row9 col1" >7</td>
#       <td id="T_91105_row9_col2" class="data row9 col2" >0</td>
#       <td id="T_91105_row9_col3" class="dat

# %%
df_net_normal.columns = df_net_normal.columns.str.strip()

# %% [markdown]
# As we can see, there is 16 different columns in those datasets, which correspond to the following :
# - **Time**: Date of acquisition
# - **mac_s**: Source MAC address
# - **mac_d**: Destination MAC address
# - **ip_s**: Source IP address
# - **ip_d**: Destination IP address
# - **sport**: Source port
# - **dport**: Destination port
# - **proto**: Protocol
# - **flags**: TCP flags - CWR | ECN | URG | ACK | PSH | RST | SYN | FIN
# - **size**: Size of the packet payload
# - **modbus_fn**: MODBUS function code
# - **n_pkt_src**: Number of packets of the same source address in the last 2 seconds
# - **n_pkt_dst**: Number of packets of the same destination address in the last 2 seconds
# - **modbus_response**: MODBUS response value
# - **label_n**: 0 if normal, 1 if attack
# - **label**: type of attack
#
# Let's have a look at the date range of each dataset, by first converting the **Time** column to the *timestamp* type :

# %% [markdown]
# df_net_attack_1['Time'] = pd.to_datetime(df_net_attack_1['Time'], errors='coerce')
# df_net_attack_2['Time'] = pd.to_datetime(df_net_attack_2['Time'], errors='coerce')
# df_net_attack_3['Time'] = pd.to_datetime(df_net_attack_3['Time'], errors='coerce')
# df_net_normal['Time'] = pd.to_datetime(df_net_normal['Time'], errors='coerce')

# %%
print(f"Unique days of df_net_attack_1: {df_net_attack_1["Time"].dt.normalize().unique().tolist()}")
print(f"Unique days of df_net_attack_2: {df_net_attack_2["Time"].dt.normalize().unique().tolist()}")
print(f"Unique days of df_net_attack_3: {df_net_attack_3["Time"].dt.normalize().unique().tolist()}")
print(f"Unique days of df_net_normal: {df_net_normal["Time"].dt.normalize().unique().tolist()}")
# Out:
# Unique days of df_net_attack_1: [Timestamp('2021-04-09 00:00:00'), NaT]
# Unique days of df_net_attack_2: [Timestamp('2021-04-19 00:00:00'), NaT]
# Unique days of df_net_attack_3: [Timestamp('2021-04-09 00:00:00'), NaT]
# Unique days of df_net_normal: [Timestamp('2021-04-09 00:00:00'), NaT]

# %% [markdown]
# Let's now concat all the datasets and remove **duplicates** and **nan**, as showed in the datasets's summaries. We first merge then remove duplicates because there might be duplicates between dataset parts, especially for the *df_net_attack_1* and *df_net_attack_3* which are the same day.

# %%
df_net = pd.concat([df_net_attack_1, df_net_attack_2, df_net_attack_3, df_net_normal])

# %%
df_net.columns
# Out:
# Index(['Time', 'mac_s', 'mac_d', 'ip_s', 'ip_d', 'sport', 'dport', 'proto',
#        'flags', 'size', 'modbus_fn', 'n_pkt_src', 'n_pkt_dst',
#        'modbus_response', 'label_n', 'label'],
#       dtype='object')

# %%
len(df_net)
# Out:
# 24306714

# %%
len(df_net[df_net["label_n"] == 0]), len(df_net[df_net["label_n"] == 1])
# Out:
# (17608422, 6698292)

# %%
df_net = df_net.dropna()
df_net = df_net.drop_duplicates()

# %%
len(df_net)
# Out:
# 10130285

# %%
len(df_net[df_net["label_n"] == 0]), len(df_net[df_net["label_n"] == 1])
# Out:
# (8565851, 1564434)

# %% [markdown]
# As we can see, we drop a lot of rows, way more attack ones than normal ones (in percentage).

# %% [markdown]
# ## Physical datasets
#
# ---
#
# TODO
